# %%
import pandas as pd

# %%
data = {
    "Name": ["Prem","Mayur","Shubham","Krish"],
    "Age":[19,25,35,17],
    "Marks":[65,35,68,90]
}

df = pd.DataFrame(data)
df

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df["Marks"]

# %%
df [["Name","Marks"]]

# %%
df[df["Marks"] >=70]

# %%
df[df["Age"] >=20]

# %%
df[(df["Age"] >16) & (df["Marks"] >=70)]

# %%
def result_status(Marks):
    if Marks >=50:
        return "Pass"
    else:
        return "Fail"

df["Result"] = df["Marks"].apply(result_status)
df

# %%
df["Result"].value_counts()

# %%
df["Marks"].mean()

# %%
df["Marks"].min()

# %%
df["Marks"].max()

# %%
df.sort_values("Marks")

# %%
df.sort_values("Marks",ascending=False)

# %%
df.sort_values("Marks",ascending=False).reset_index(drop=True)

# %%
df["Grade"] = df["Marks"].apply(
    lambda x: "A" if x >= 75 else "B"
)

# %%
df

# %%
df["Grade"].value_counts()

# %%
df[df["Grade"] =="A"]

# %%
df

# %%
df.groupby("Age")["Marks"].mean()

# %%
df.groupby("Grade")["Name"].count()

# %%
df.groupby("Age")["Marks"].agg(["mean","max","min","count"])

# %%
df.groupby("Age")["Marks"].mean().sort_values(ascending=False)

# %%
df

# %%
df.groupby("Age")["Marks"].mean()

# %%
df["Age"].value_counts()

# %%
df["Marks"].value_counts()

# %%
df.sort_values("Marks")

# %%
df.sort_values("Marks", ascending=False)

# %%
df.sort_values("Marks", ascending=False).reset_index(drop=True)

# %%
df ["Rank"] = df["Marks"].rank(ascending=False)
df

# %% [raw]
# df.sort_values("Marks",ascending=False).head(2)

# %%
df.sort_values("Marks").head(2)

# %%
final_df = df.sort_values("Marks",ascending=False).reset_index(drop=True)
df

# %%
total_student = final_df.shape[0]
total_student

# %%
average_marks = final_df["Marks"].mean
average_marks

# %%
top_scorer = final_df.iloc[0]
top_scorer

# %%
lower_scorer = final_df.iloc[-1]
lower_scorer

# %%
final_df.head(2)
