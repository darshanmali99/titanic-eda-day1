# %%
import pandas as pd 
import numpy as np 

data = {
    "Name" :["Prem", "Shubham", "Mayur", "Krish", "Mayur"],
    "Age" :[19,25, np.nan,17,25],
    "Marks" :[65,35,None,38,35],
    "City" :["Nashik", "Pune", "nashk", "Mumbai", "Pune"]
}
df = pd.DataFrame(data)
df
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  Nashik
# 1  Shubham  25.0   35.0    Pune
# 2    Mayur   NaN    NaN   nashk
# 3    Krish  17.0   38.0  Mumbai
# 4    Mayur  25.0   35.0    Pune

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     4 non-null      float64
#  2   Marks   4 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.isnull()
# Out:
#     Name    Age  Marks   City
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False   True   True  False
# 3  False  False  False  False
# 4  False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# City     0
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  Nashik
# 1  Shubham  25.0   35.0    Pune
# 3    Krish  17.0   38.0  Mumbai
# 4    Mayur  25.0   35.0    Pune

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Marks"] =df["Marks"].fillna(df["Age"].mean())

# %%
df["City"] =df["City"].str.capitalize()

# %%
df["City"].unique()
# Out:
# array(['Nashik', 'Pune', 'Nashk', 'Mumbai'], dtype=object)

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      float64
#  2   Marks   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  Nashik
# 1  Shubham  25.0   35.0    Pune
# 2    Mayur  21.5   21.5   Nashk
# 3    Krish  17.0   38.0  Mumbai
# 4    Mayur  25.0   35.0    Pune

# %%
df["City"] = df["City"].str.lower().str.strip()
df
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  nashik
# 1  Shubham  25.0   35.0    pune
# 2    Mayur  21.5   21.5   nashk
# 3    Krish  17.0   38.0  mumbai
# 4    Mayur  25.0   35.0    pune

# %%
df["City"] = df["City"].replace("nashik","nashik")

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      float64
#  2   Marks   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes
# Name     0
# Age      0
# Marks    0
# City     0
# dtype: int64

# %% [raw]
# df.groupby("City")["Marks"].mean()

# %%
df.sort_values("Marks",ascending=False)
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  nashik
# 3    Krish  17.0   38.0  mumbai
# 1  Shubham  25.0   35.0    pune
# 4    Mayur  25.0   35.0    pune
# 2    Mayur  21.5   21.5   nashk

# %%
df.describe()
# Out:
#              Age      Marks
# count   5.000000   5.000000
# mean   21.500000  38.900000
# std     3.570714  15.931102
# min    17.000000  21.500000
# 25%    19.000000  35.000000
# 50%    21.500000  35.000000
# 75%    25.000000  38.000000
# max    25.000000  65.000000

# %%
Q1 = df["Marks"].quantile(0.25)
Q3 = df["Marks"].quantile(0.75)

IQR =Q3 - Q1

lower_limit = Q1 - 1.5 *IQR
upper_limit = Q3 - 1.5 *IQR

# %%
outliers = df[(df["Marks"] < lower_limit) | (df["Marks"] > upper_limit)]
outliers
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  nashik
# 1  Shubham  25.0   35.0    pune
# 2    Mayur  21.5   21.5   nashk
# 3    Krish  17.0   38.0  mumbai
# 4    Mayur  25.0   35.0    pune

# %%
df_cleaan = df[(df["Marks"] > lower_limit) & (df["Marks"] <= upper_limit)]

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=df["Marks"])
plt.title("Boxplot Of Marks (Outlier detection)")
plt.show()

# %%
df["City"] = df["City"].str.lower().str.strip()

# %%
df["City"] =df["City"].replace("nashk","nashik")

# %%
df["City"].unique()
# Out:
# array(['nashik', 'pune', 'mumbai'], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       Name   Age  Marks    City
# 0     Prem  19.0   65.0  Nashik
# 1  Shubham  25.0   35.0    Pune
# 2    Mayur   NaN    NaN   nashk
# 3    Krish  17.0   38.0  Mumbai
# 4    Mayur  25.0   35.0    Pune

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'city'], dtype='object')

# %%
df.dtypes
# Out:
# name      object
# age      float64
# marks    float64
# city      object
# dtype: object

# %%
df["age"] = df["age"].fillna(df["age"].mean())

# %%
df["age"] = df ["age"].round().astype(int)

# %%
df.dtypes
# Out:
# name      object
# age        int64
# marks    float64
# city      object
# dtype: object

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'city'], dtype='object')

# %%
df.dtypes
# Out:
# name      object
# age        int64
# marks    float64
# city      object
# dtype: object

# %%
df["marks"].isnull().sum()
# Out:
# np.int64(1)

# %%
df["marks"] = df["marks"].fillna(df["marks"].mean())

# %%
df["marks"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["marks"] = df["marks"].astype(int)

# %%
df.dtypes
# Out:
# name     object
# age       int64
# marks     int64
# city     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# name     0
# age      0
# marks    0
# city     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['age'].min(), df['age'].max()
# Out:
# (17, 25)

# %%
df['marks'].min(), df['marks'].max()
# Out:
# (35, 65)

# %%
df['city'].value_counts()
# Out:
# city
# Pune      2
# Nashik    1
# nashk     1
# Mumbai    1
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["city"] = df["city"].replace({"nashk": "nashik"})

# %%
df.info()
df.isnull().sum()
df.dtypes
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   marks   5 non-null      int64
#  3   city    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#       name  age  marks    city
# 0     Prem   19     65  Nashik
# 1  Shubham   25     35    Pune
# 2    Mayur   22     43  nashik
# 3    Krish   17     38  Mumbai
# 4    Mayur   25     35    Pune

# %%
df["city"] = df["city"].replace({"Nashik": "nashik"})

# %%
df.info()
df.isnull().sum()
df.dtypes
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   marks   5 non-null      int64
#  3   city    5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#       name  age  marks    city
# 0     Prem   19     65  nashik
# 1  Shubham   25     35    Pune
# 2    Mayur   22     43  nashik
# 3    Krish   17     38  Mumbai
# 4    Mayur   25     35    Pune

# %%
df["age_group"] = df["age"].apply(lambda x: "Adult" if x >= 18 else "Minor")

# %%
df["result_status"] = df["marks"].apply(lambda x: "Pass" if x >=40 else "Fail")

# %%
def performance(marks):
    if marks >= 70:
        return "Excellent"
    elif marks >= 50:
        return "Good"
    else:
        return "Poor"

df["performance_level"] = df["marks"].apply(performance)

# %%
df.head()
# Out:
#       name  age  marks    city age_group result_status performance_level
# 0     Prem   19     65  nashik     Adult          Pass              Good
# 1  Shubham   25     35    Pune     Adult          Fail              Poor
# 2    Mayur   22     43  nashik     Adult          Pass              Poor
# 3    Krish   17     38  Mumbai     Minor          Fail              Poor
# 4    Mayur   25     35    Pune     Adult          Fail              Poor

# %%
df.groupby("city")["marks"].mean()
# Out:
# city
# Mumbai    38.0
# Pune      35.0
# nashik    54.0
# Name: marks, dtype: float64

# %%
df["age_group"].value_counts()
# Out:
# age_group
# Adult    4
# Minor    1
# Name: count, dtype: int64

# %%
df["result_status"].value_counts()
# Out:
# result_status
# Fail    3
# Pass    2
# Name: count, dtype: int64

# %%
df[df["result_status"] == "Pass"].groupby("city").size()
# Out:
# city
# nashik    2
# dtype: int64

# %%
df["performance_level"].value_counts()
# Out:
# performance_level
# Poor    4
# Good    1
# Name: count, dtype: int64

# %%
# Day 5: Exploratory Data Analysis (EDA)

# %%
df["marks"].describe()
# Out:
# count     5.000000
# mean     43.200000
# std      12.617448
# min      35.000000
# 25%      35.000000
# 50%      38.000000
# 75%      43.000000
# max      65.000000
# Name: marks, dtype: float64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.histplot(df["marks"], bins=10, kde=True)
plt.title("Distibution of Marks")
plt.show ()

# %%
df["city"].value_counts()
# Out:
# city
# nashik    2
# Pune      2
# Mumbai    1
# Name: count, dtype: int64

# %%
sns.countplot(x="city", data=df)
plt.title("Student Count By City")
plt.show()

# %%
sns.boxplot(x="city", y="marks", data=df)
plt.title("Marks distribution of city")
plt.show()

# %%
sns.countplot(x="performance_level", hue="age_group", data=df)
plt.title("Performace by age")
plt.show()

# %%
df["city"].value_counts()
# Out:
# city
# nashik    2
# Pune      2
# Mumbai    1
# Name: count, dtype: int64

# %%
df["performance_level"].value_counts()
# Out:
# performance_level
# Poor    4
# Good    1
# Name: count, dtype: int64

# %%
df["age_group"].value_counts()
# Out:
# age_group
# Adult    4
# Minor    1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="city", data=df)
plt.title("students by city")
plt.show()

# %%
sns.countplot(x="performance_level", data=df)
plt.title("performance level distribution")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.boxplot(x="city", y="marks", data=df)
plt.title("marks distribution by city")
plt.show()

# %%
sns.countplot(x="performance_level", hue="age_group", data=df)
plt.title("performance by age group")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[df["result_status"] == "Pass"] ["city"].value_counts()
# Out:
# city
# nashik    2
# Name: count, dtype: int64

# %%
sns.countplot(x="city", data=df[df["result_status"] == "Pass"])
plt.title("Pass Count by City")
plt.show()

# %%
#day 6 deep eda thinking

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation heatmap")
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'age', 'marks', 'city', 'age_group', 'result_status',
#        'performance_level'],
#       dtype='object')

# %%
df[['age', 'marks']].agg(['mean', 'median'])
# Out:
#          age  marks
# mean    21.6   43.2
# median  22.0   38.0

# %%
df["marks"].mean()
# Out:
# np.float64(43.2)

# %%
df.groupby('performance_level') ['marks'].agg(['mean','median'])
# Out:
#                     mean  median
# performance_level
# Good               65.00    65.0
# Poor               37.75    36.5

# %%
df['result_status'].value_counts(normalize=True)
# Out:
# result_status
# Fail    0.6
# Pass    0.4
# Name: proportion, dtype: float64

# %%
df.groupby('city')['result_status'].value_counts(normalize=True)
# Out:
# city    result_status
# Mumbai  Fail             1.0
# Pune    Fail             1.0
# nashik  Pass             1.0
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

sns.scatterplot(data=df, x='age', y='marks' )
plt.title("Age vs Marks")
plt.show()

# %%
sns.boxplot(data=df, x='result_status', y='marks')
plt.title("marks distribution by result status")
plt.show()
